# %%
! pip install visual_midi
# Out:
# Requirement already satisfied: visual_midi in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: bokeh>=2.0.2 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from visual_midi) (2.1.1)
# Requirement already satisfied: pretty-midi>=0.2.8 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from visual_midi) (0.2.9)
# Requirement already satisfied: tornado>=5.1 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (6.0.4)
# Requirement already satisfied: packaging>=16.8 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (20.4)
# Requirement already satisfied: PyYAML>=3.10 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (5.3.1)
# Requirement already satisfied: numpy>=1.11.3 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (1.18.5)
# Requirement already satisfied: pillow>=4.0 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (7.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (2.8.1)
# Requirement already satisfied: Jinja2>=2.7 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (2.11.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=2.0.2->visual_midi) (3.7.4.2)
# Requirement already satisfied: six in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from pretty-midi>=0.2.8->visual_midi) (1.15.0)
# Requirement already satisfied: mido>=1.1.16 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from pretty-midi>=0.2.8->visual_midi) (1.2.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from packaging>=16.8->bokeh>=2.0.2->visual_midi) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/lanzhang/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.7->bokeh>=2.0.2->visual_midi) (1.1.1)

# %%
from visual_midi import Plotter
from visual_midi import Preset
from pretty_midi import PrettyMIDI

# %%
preset = Preset(plot_width=850)
plotter = Plotter(preset, plot_max_length_bar=4)
# Original piece's (Bach's Violin Concerto in A Minor) MIDI file
pm = PrettyMIDI("original.mid")
plotter.show_notebook(pm)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1863">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fde9d973-a862-4e84-a460-88d7f4ff6574" data-root-id="1862"></div>
# Column(id='1862', ...)

# %%
preset = Preset(plot_width=850)
plotter = Plotter(preset, plot_max_length_bar=4)
# 4th order composed piece's midi file
pm = PrettyMIDI("composed_song.mid")
plotter.show_notebook(pm)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2764">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fbf6c523-22b5-4893-bb22-15c8d83ce4d8" data-root-id="2763"></div>
# Column(id='2763', ...)
